# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\91866

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\91866\Downloads\Mall_Customers.csv")
df.head()  # to check first 5 rows
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df = df.drop_duplicates()

# %%
# 2. Remove leading/trailing spaces from column names and lowercase
cols = [col.strip().lower().replace(' ', '_') for col in df.columns]
df.columns = cols

# %%
 
# 4. Handle missing values - drop rows where any column is missing (for demonstration)
df = df.dropna()

# %%
# 5. Check and fix data types
if 'age' in df.columns:
    df['age'] = pd.to_numeric(df['age'], errors='coerce').astype('Int64')
if 'annual_income_k' in df.columns:
    df['annual_income_k'] = pd.to_numeric(df['annual_income_k'], errors='coerce').astype('Int64')
if 'spending_score_1_100' in df.columns:
    df['spending_score_1_100'] = pd.to_numeric(df['spending_score_1_100'], errors='coerce').astype('Int64')

# If there were date columns, convert them here (none detected in sample preview)

# %%
# Save to csv
df.head(10).to_csv('Mall_Customers_cleaned_sample.csv', index=True)
df.info(), df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customerid              200 non-null    int64
#  1   gender                  200 non-null    object
#  2   age                     200 non-null    Int64
#  3   annual_income_(k$)      200 non-null    int64
#  4   spending_score_(1-100)  200 non-null    int64
# dtypes: Int64(1), int64(3), object(1)
# memory usage: 9.6+ KB
# (None,
#     customerid  gender  age  annual_income_(k$)  spending_score_(1-100)
#  0           1    Male   19                  15                      39
#  1           2    Male   21                  15                      81
#  2           3  Female   20                  16                       6
#  3           4  Female   23                  16                      77
#  4           5  Female   31                  17                      40
# ...
